# %% [markdown]
# ## DATA ANALYSIS ##

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('Data for Sales Analysis 1.xlsx')
df
# Out:
#       SalesID         Product Name   Product Category Sales Date  \
# 0           1  External Hard Drive        Electronics 2023-05-11
# 1           2    Bluetooth Speaker        Electronics 2024-06-17
# 2           3        Leather Boots            Fashion 2023-01-02
# 3           4         Air Purifier    Home Appliances 2023-01-02
# 4           5            Treadmill  Sports & Outdoors 2024-08-06
# ...       ...                  ...                ...        ...
# 1353     1354         Facial Serum    Health & Beauty 2024-01-17
# 1354     1355        Mystery Novel      Books & Media 2024-01-18
# 1355     1356   Facial Moisturizer    Health & Beauty 2024-01-19
# 1356     1357        Fiction Novel      Books & Media 2024-01-20
# 1357     1358        Sweater Dress            Fashion 2024-01-21
#
#       Sales Amount  Quantity Sold                Region Customer ID  \
# 0            195.0              3                Europe    CUST1091
# ...

# %%
df1 = df['Customer Feedback'].value_counts()
df1
# Out:
# Poor packaging                46
# Satisfied with my purchase    45
# Quick shipping                45
# Damaged on arrival            44
# Color not as shown            44
# Not as described              44
# Will shop again               44
# Exceeds expectations          43
# Perfect fit                   42
# Too expensive                 42
# I love it                     42
# Not worth the money           42
# Could be better               42
# Delays in delivery            42
# Excellent quality             42
# Good value for money          42
# Terrible support              41
# Fast delivery                 41
# Would buy again               40
# Not recommended               40
# Missing accessories           40
# Great product                 38
# Do not recommend              38
# Won't buy again               38
# Will return                   37
# Very fast service             37
# Nice experience               36
# Arrived late                  36
# ...

# %%
df['Customer assessment of Sales Rep'] = df['Customer assessment of Sales Rep'].replace('Postive','Positive')
df
# Out:
#       SalesID         Product Name   Product Category Sales Date  \
# 0           1  External Hard Drive        Electronics 2023-05-11
# 1           2    Bluetooth Speaker        Electronics 2024-06-17
# 2           3        Leather Boots            Fashion 2023-01-02
# 3           4         Air Purifier    Home Appliances 2023-01-02
# 4           5            Treadmill  Sports & Outdoors 2024-08-06
# ...       ...                  ...                ...        ...
# 1353     1354         Facial Serum    Health & Beauty 2024-01-17
# 1354     1355        Mystery Novel      Books & Media 2024-01-18
# 1355     1356   Facial Moisturizer    Health & Beauty 2024-01-19
# 1356     1357        Fiction Novel      Books & Media 2024-01-20
# 1357     1358        Sweater Dress            Fashion 2024-01-21
#
#       Sales Amount  Quantity Sold                Region Customer ID  \
# 0            195.0              3                Europe    CUST1091
# ...

# %%
df2 = df['Customer assessment of Sales Rep'].value_counts()
df2
# Out:
# Positive    618
# Neutral     370
# Negative    370
# Name: Customer assessment of Sales Rep, dtype: int64

# %%
df['Product Quality'] = df['Customer Feedback']

# %%
import re
from collections import Counter
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Sample sales data with customer feedback
df = {
    'Customer Feedback': ["Poor packaging",
                          "Satisfied with my purchase",
                          "Quick shipping",
                          "Damaged on arrival",
                          "Color not as shown",
                          "Not as described",
                          "Will shop again",
                          "Exceeds expectations",
                          "Perfect fit",
                          "Too expensive",
                          "I love it",
                          "Not worth the money",
                          "Could be better",
                          "Delays in delivery",
                          "Excellent quality",
                          "Good value for money",
                          "Terrible support",
                          "Fast delivery",
                          "Would buy again",
                          "Not recommended",
                          "Missing accessories",
                          "Great product",
                          "Do not recommend",
                          "Won't buy again",
                          "Will return",
                          "Very fast service",
                          "Nice experience",
                          "Arrived late",
                          "Item as described",
                          "Fantastic experience",
                          "Very satisfied",
                          "Mislabelled",
                          "Top notch",
                          "Returning this item"]}

# Pre-processing function
def preprocess_text(text):
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words('english'))
    text = text.lower()
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # Remove punctuation
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Assign feedback themes
themes = []
for feedback in df['Customer Feedback']:
    cleaned_feedback = preprocess_text(feedback)
    
    if 'product' in cleaned_feedback or 'top' in cleaned_feedback or 'great' in cleaned_feedback or 'quality' in cleaned_feedback or 'color' in cleaned_feedbackor or 'excellent' in cleaned_feedback:
        theme = 'Product Quality'
    elif 'delivery' in cleaned_feedback or 'missing' in cleaned_feedback or 'arrival' in cleaned_feedback or 'late' in cleaned_feedback or 'shipping' in cleaned_feedback:
        theme = 'Delivery Issue'
    elif 'disappointed' in cleaned_feedback or 'service' in cleaned_feedback or 'return' in cleaned_feedback or 'terrible' in cleaned_feedback or 'better' in cleaned_feedback or 'returning' in cleaned_feedback:
        theme = 'Customer Service'
    elif 'expensive' in cleaned_feedback or 'worth' in cleaned_feedbackor or 'money' in cleaned_feedback:
        theme = 'Value for Money'
    elif 'experience' in cleaned_feedback or 'delivery' in cleaned_feedback:
        theme = 'Experience with Purchase'
    elif 'exact' in cleaned_feedback or 'described' in cleaned_feedback:
        theme = 'Product Description Accuracy'
    else:
        theme = 'Experience with Purchase'
    
    themes.append(theme)

# Update DataFrame with themes
df['Suggested Feedback Themes'] = themes

# Calculate frequency and percentage
theme_freq = df['Suggested Feedback Theme'].value_counts()
theme_percent = (df['Suggested Feedback Theme'].value_counts(normalize=True)) * 100

# Create table
table = pd.DataFrame({
    'Suggested Feedback Theme': theme_freq.index,
    'Frequency': theme_freq.values,
    'Percentage': theme_percent.values
})

# Print table
print(table)
# Out:
#   File "<tokenize>", line 60
#     elif 'delivery' in cleaned_feedback or 'missing' in cleaned_feedback or 'arrival' in cleaned_feedback or 'late' in cleaned_feedback or 'shipping' in cleaned_feedback:
#     ^
# IndentationError: unindent does not match any outer indentation level
